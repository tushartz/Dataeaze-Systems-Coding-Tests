# %% [markdown]
# <a href="https://colab.research.google.com/github/tushartz/Dataeaze-Systems-Coding-Tests/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python** **Basics**

# %%
import kagglehub
path = kagglehub.dataset_download("pavansubhasht/ibm-hr-analytics-attrition-dataset")
# Out:
# ...
# 100%|██████████| 50.1k/50.1k [00:00<00:00, 35.3MB/s]
# Extracting files...

# %%
print('hello World')
# Out:
# hello World

# %%
X,Y,Z = 1,2,'Tushar'
print(X,Y,Z)
# Out:
# 1 2 Tushar

# %%
def add_num(X,Y):
  return X+Y

print(add_num(2,3))
# Out:
# 5

# %%
#casting

x = int('1')
y = int(2.9)
z = int(5)
print(x,y,z)

x = str('j1')
y = str(2.9)
z = str(5)
print(x,y,z)

x = float('1')
y = float(2.9)
z = float(5)
print(x,y,z)
# Out:
# 1 2 5
# j1 2.9 5
# 1.0 2.9 5.0

# %%
#String split

X = 'rggvb rtggb tertr'
print(X[2:6])
print(X[:6])
print(X[2:-6])
print(X[-6:-2])
# Out:
# gvb
# rggvb
# gvb rtggb
#  ter
