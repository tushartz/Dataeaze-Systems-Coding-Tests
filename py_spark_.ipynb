# %% [markdown]
# <a href="https://colab.research.google.com/github/tushartz/Dataeaze-Systems-Coding-Tests/blob/main/py_spark_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType
from pyspark.sql.functions import col

# Initialize Spark
spark = SparkSession.builder \
    .appName("DataProcessing") \
    .master("local[*]") \
    .getOrCreate()

# Create sample data
data = [("Alice", 34), ("Bob", 45), ("Cathy", 29)]
df = spark.createDataFrame(data, ["Name", "Age"])

# Show data
df.show()

# Perform operations
result = df.filter(col("Age") > 30).collect()
print(result)

# Stop Spark session (important for resource cleanup)
spark.stop()
# Out:
# +-----+---+
# | Name|Age|
# +-----+---+
# |Alice| 34|
# |  Bob| 45|
# |Cathy| 29|
# +-----+---+
#
# [Row(Name='Alice', Age=34), Row(Name='Bob', Age=45)]

# %%
spark = SparkSession.builder.appName("DataProcessing").master("local[*]").getOrCreate()
